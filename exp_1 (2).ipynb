# %%
#print and new line function:
print("banana","apple","orange",sep="\n")

#Types:
w,x,y,z=True,"Rahul",9,2.5
print(type(x))
print(type(y))
print(type(z))
print(type(w))

#mathematical operations:
a,b=2,4
print("add=",a+b)
print("sub=",b-a)
print("multi=",a+b)
print("div=",b/a)
print("expo=",a**b)
# Out:
# banana
# apple
# orange
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# add= 6
# sub= 2
# multi= 6
# div= 2.0
# expo= 16

# %%
#Generalized mathematical expression:
a=int(input("Enter first number:"))
b=int(input("Enter second number:"))
print("add=",a+b)
print("sub=",b-a)
print("multi=",a*b)
print("div=",b/a)
print("expo=",a**b)
# Out:
# Enter first number:4
# Enter second number:6
# add= 10
# sub= 2
# multi= 24
# div= 1.5
# expo= 4096

# %%
#area of circle:
import math
r=float(input("Radius of the circle:"))
area= math.pi*(r**2)
print(area)
# Out:
# Radius of the circle:4
# 50.26548245743669

# %%
import math
print(math.log10(100))
# Out:
# 2.0

# %%
a=int(input("Enter a:"))
b=int(input("Enter b:"))
if a>b:
  print("a is larger")
else:
  print("b is larger")
# Out:
# Enter a:6
# Enter b:7
# b is larger
